# %%
import pandas as pd

# %% [markdown]
# #### ORIGEN DATASETS
# DATASETS OctopusTeam
# https://www.kaggle.com/datasets/octopusteam/full-hbo-max-dataset
# https://www.kaggle.com/datasets/octopusteam/full-amazon-prime-dataset
# https://www.kaggle.com/datasets/octopusteam/full-netflix-dataset
# DATASET Top Movies: Shreya Chinchane
# https://www.kaggle.com/datasets/chinchaneshreya/imdb-top-250-movies-data
# DATASET Top Shows: Anand Shaw
# https://www.kaggle.com/datasets/anandshaw2001/imdb-top-250-tv-shows?resource=download
# DATASET CON MIS CALIFICACIONES, desde imdb tienen una función para descargarte tus puntuaciones como csv.
# https://www.imdb.com/exports

# %%
#Cargo todos los datasets Me he quedado con los nuevos para normalizar la info (mirar versiones anteriores)
netflix = pd.read_csv('../data/netflix_titles_nuevo.csv')
amazon = pd.read_csv('../data/amazon_titles_nuevo.csv')
hbo = pd.read_csv('../data/hbo_titles.csv')
imdb_top_movies = pd.read_csv('../data/imdb_top_250_movies.csv', encoding='latin1')
imdb_top_tv = pd.read_csv('../data/imdb_Top_250_TV_Shows.csv')
mis_calificaciones = pd.read_csv('../data/mis_calificaciones_imdb.csv')

# %%
#Creo función para examinar los datasets
def examinar_dataset(df,df_entrecomillado):
    print(f"Examinando dataframe: {df_entrecomillado} \n")
    print("\nInformación del dataset:")
    print(df.info())
    print("\nValores nulos:")
    print(df.isna().sum())
    print("Primeras 5 filas:\n")
    display(df.head()) #Con este "display" puedo hacer todas las ejecuciones de esta función en la misma celda y que todos los head se vean bien
    #Con el return solo me mostraba el último

# %%
examinar_dataset(netflix, "netflix")
examinar_dataset(amazon, "amazon")
examinar_dataset(hbo, "hbo")
examinar_dataset(imdb_top_movies, "imdb_top_movies")
examinar_dataset(imdb_top_tv, "imdb_top_tv")
examinar_dataset(mis_calificaciones, "mis_calificaciones")
# Out:
# Examinando dataframe: netflix
#
#
# Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20195 entries, 0 to 20194
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               19684 non-null  object
#  1   type                20195 non-null  object
#  2   genres              19925 non-null  object
#  3   releaseYear         20182 non-null  float64
#  4   imdbId              18887 non-null  object
#  5   imdbAverageRating   18734 non-null  float64
#  6   imdbNumVotes        18734 non-null  float64
#  7   availableCountries  20195 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 1.2+ MB
# None
#
# Valores nulos:
# title                  511
# type                     0
# genres                 270
# releaseYear             13
# imdbId                1308
# imdbAverageRating     1461
# imdbNumVotes          1461
# availableCountries       0
# ...
