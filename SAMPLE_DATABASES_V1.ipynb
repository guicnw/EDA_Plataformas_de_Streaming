# %%
import pandas as pd

# %% [markdown]
# 5 DATASETS.
# 1. top 250 series valoradas en imdb (250 rows × 5 columns)
# 2. top 250 peliculas valoradas en imdb (250 rows × 8 columns)
# 3. Contenido disponible en Netflix (8807 rows × 12 columns)
# 4. Contenido disponible en Amazon Prime Video (9668 rows × 12 columns)
# 5. Contenido disponible en HBO (7342 rows × 8 columns)

# %%
df_top_series=pd.read_csv("./Data/imdb_Top_250_TV_Shows.csv")

# %%
df_top_series
# Out:
#                         Shows Name Release Year Episodes  Rating  \
# 0                     Breaking Bad    2008–2013   62 eps     9.5
# 1                  Planet Earth II         2016    6 eps     9.5
# 2                     Planet Earth         2006   11 eps     9.4
# 3                 Band of Brothers         2001   10 eps     9.4
# 4                        Chernobyl         2019    5 eps     9.3
# ..                             ...          ...      ...     ...
# 245                          Umbre    2014–2019   21 eps     8.7
# 246                    Foyle's War    2002–2015   28 eps     8.6
# 247                        Gintama    2005–2021  375 eps     8.7
# 248  The Great British Baking Show        2010–  189 eps     8.6
# 249                      Community    2009–2015  110 eps     8.5
#
#     Rating given by people
# 0                   (2.2M)
# 1                   (163K)
# 2                   (224K)
# 3                   (547K)
# 4                   (912K)
# ...

# %%
df_top_movies=(pd.read_csv("./Data/imdb_top_250_movies.csv",encoding='latin1'))

# %%
df_top_movies
# Out:
#                          Title  Release_year Duration  Duration_in_minutes  \
# 0     The Shawshank Redemption          1994   2h 22m                  142
# 1                The Godfather          1972   2h 55m                  175
# 2              The Dark Knight          2008   2h 32m                  152
# 3        The Godfather Part II          1974   3h 22m                  202
# 4                 12 Angry Men          1957   1h 36m                   96
# ..                         ...           ...      ...                  ...
# 245              Amores Perros          2000   2h 34m                  154
# 246                    Rebecca          1940   2h 10m                  130
# 247                   The Help          2011   2h 26m                  146
# 248  A Silent Voice: The Movie          2016   2h 10m                  130
# 249             Cool Hand Luke          1967    2h 7m                  127
#
#      Rating Content_rating No_of_votes  No_of_votes_numeric
# ...

# %%
df_mis_calificaciones=pd.read_csv("./Data/mis_calificaciones_imdb.csv")
df_mis_calificaciones #Mis calificaciones personales hechas en imdb.
# Out:
#           Const  Your Rating  Date Rated                          Title  \
# 0     tt0307901            7  2024-11-08                La última noche
# 1     tt0106856            7  2024-09-13                Un día de furia
# 2     tt4550098            7  2024-08-31             Animales nocturnos
# 3    tt14230458            7  2024-07-12               Pobres criaturas
# 4     tt2543164            9  2024-07-12                     La llegada
# ..          ...          ...         ...                            ...
# 192   tt0482571            9  2020-08-16  El truco final (El prestigio)
# 193   tt1596363            7  2020-08-16                La gran apuesta
# 194   tt0268978            8  2020-08-16          Una mente maravillosa
# 195   tt0407887            8  2020-08-16                    Infiltrados
# 196   tt0264464            9  2020-08-16             Atrápame si puedes
#
#           Original Title                                    URL Title Type  \
# ...

# %%
df_netflix=pd.read_csv("./Data/netflix_titles.csv")

# %%
df_netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_amazon=pd.read_csv("./Data/amazon_prime_titles.csv")

# %%
df_amazon
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
df_hbo=pd.read_csv("./Data/hbo_titles.csv")

# %%
df_hbo
# Out:
#                                       title   type                     genres  \
# 0                         The Fifth Element  movie  Action, Adventure, Sci-Fi
# 1                                   Jarhead  movie      Biography, Drama, War
# 2                                Unforgiven  movie             Drama, Western
# 3     Eternal Sunshine of the Spotless Mind  movie     Drama, Romance, Sci-Fi
# 4                     A History of Violence  movie       Action, Crime, Drama
# ...                                     ...    ...                        ...
# 7337         Girl Scout Cookie Championship     tv                 Reality-TV
# 7338                      An American Story     tv                 Reality-TV
# 7339                                    NaN     tv                    Reality
# 7340                         7 Chances Para     tv                     Comedy
# 7341      Luva de Pedreiro: O Rei da Jogada     tv         Documentary, Sport
#
# ...
